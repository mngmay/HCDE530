# %% [markdown]
# # Week 5 — Analysis Notebook
#
# **Your name:**  May Ng
# **Dataset:**  Ravelry Patterns in 2026
# **Date:**  5/5/2026

# %%
# Setup — run this cell first. # May's note - make sure to change the kernel to the virtual env!
# If any package is missing, it will install automatically
import subprocess, sys

def install(pkg):
    subprocess.check_call([sys.executable, "-m", "pip", "install", pkg, "-q"])

for pkg in ["pandas", "plotly", "kaleido", "nbformat"]:
    try:
        __import__(pkg)
    except ImportError:
        print(f"Installing {pkg}...")
        install(pkg)

import pandas as pd
import plotly.express as px

print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# --

# %% [markdown]
# ** What does df.head() do? **
# df.head() returns the first 5 rows of data available in the data set as the default. I can pass an integer to get a specific count of rows. For my data, it returns returns the first 5 projects based on project creation date, pulled starting from July 2025. This means our first results will be aligned with the season summer.

# %% [markdown]
# ---

# %%
# Load your dataset
# Replace 'your_dataset.csv' with your actual filename.
# The file should be in the same folder as this notebook.
# If you're loading from an API result, replace pd.read_csv() with the appropriate call.
#
# Example (app review dataset from class):
# df = pd.read_csv('app_reviews_demo.csv')

df = pd.read_csv('data/ravelry_patterns_2026.csv')  # ← replace with your filename

print(df.shape)
df.head()
# Out:
# (7332, 21)
#    month_collected  season     craft  pattern_id            pattern_name  \
# 0                7  Summer  knitting     7480818             CPH Sweater
# 1                7  Summer  knitting     7478239  Harvest Flower Sweater
# 2                7  Summer  knitting     1133877           Old Fashioned
# 3                7  Summer  knitting     7495801        Melt the ICE Hat
# 4                7  Summer  knitting      162969           Wolf Cardigan
#
#   published_date       category                         yarn_weight  \
# 0     2025-11-01       Pullover                             Worsted
# 1     2025-11-01       Pullover                                  DK
# 2     2021-04-01       Pullover                             Worsted
# 3     2026-01-01  Beanie, Toque  Any gauge - designed for any gauge
# 4            NaN       Cardigan                               Bulky
#
#          fiber  projects_count  ...  queued_projects_count  rating_average  \
# ...

# %% [markdown]
# ** What does df.info() do? **
# df.info() provides a table regarding the data of my dataset. It allows me to see the index, column name, count of each column and whether it's null or not and type. For my data, I can see that there's a mix of integers, strings, and floats, and have all non-null counts which means all columns are returning data.

# %%
# Check column types and missing values
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7332 entries, 0 to 7331
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month_collected            7332 non-null   int64
#  1   season                     7332 non-null   str
#  2   craft                      7332 non-null   str
#  3   pattern_id                 7332 non-null   int64
#  4   pattern_name               7332 non-null   str
#  5   published_date             6744 non-null   str
#  6   category                   7332 non-null   str
#  7   yarn_weight                7332 non-null   str
#  8   fiber                      7332 non-null   str
#  9   projects_count             7320 non-null   float64
#  10  favorites_count            7320 non-null   float64
#  11  queued_projects_count      7320 non-null   float64
#  12  rating_average             7320 non-null   float64
#  13  rating_count               7320 non-null   float64
# ...

# %% [markdown]
# ** What does df['column'].value_counts() do? **
# For my data, I used df['craft'].value_counts() to count the values for the craft column. This gives me the values of how many knitting and how many crochet projects there are. Based on my data, I can see that crochet projects outnumber knitting!

# %%
# Check column types and missing values
df['craft'].value_counts()
# Out:
# craft
# crochet     4068
# knitting    3264
# Name: count, dtype: int64

# %% [markdown]
# ** What does df.isnull().sum() do? **
#
# df.isnull().sum() returns a count of how many null values exist in my dataset. Here I can see that published_date is the category with the most null values, along with designer data such as first published and years of experience returning a high amount of null values. This makes sense, as the way I'm calculating a designer's years of experience relies on their first published date, and their first published date relies on having a valid published_date value!

# %%
df.isnull().sum()
# Out:
# month_collected                0
# season                         0
# craft                          0
# pattern_id                     0
# pattern_name                   0
# published_date               588
# category                       0
# yarn_weight                    0
# fiber                          0
# projects_count                12
# favorites_count               12
# queued_projects_count         12
# rating_average                12
# rating_count                  12
# designer_id                   12
# designer_name                  0
# designer_first_published     516
# designer_years_experience    516
# designer_total_projects       12
# designer_total_favorites      12
# designer_pattern_count        12
# dtype: int64
